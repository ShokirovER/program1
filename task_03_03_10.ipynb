# %% [markdown]
# <a href="https://colab.research.google.com/github/ShokirovER/program1/blob/main/task_03_03_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание task_03_03_10.
#
# Выполнил: Шокиров Е.Р.
# Группа: ЦИБ-241



"""
Ошибки (номера строк через пробел, данная строка - №2): !!!
"""


# В программе хранится словарь вступительных экзаменов вида Предмет=Баллы.
# Узнать, проходит ли абитуриент на специальность, если нужно сдать
# все перечисленные экзамены с не меньшим количеством баллов.

необходимые_экзамены = {
    "Информатика": 80,
    "Математика": 85,
    "Русский язык": 75
}

print("""Для определения возможности поступления, необходима информация о Вас.

Для ввода экзамена и баллов введите их через |: Химия | 40.
Для завершения ввода нажмите Enter.
""")

сданные_экзамены = {}
while True:
    ввод = input("").strip()
    if ввод == "":
        break

    экзамен, балл = [x.strip() for x in ввод.split("|")]
    сданные_экзамены[экзамен] = int(балл)

print("Ваши экзамены:")
for i, (экзамен, балл) in enumerate(сданные_экзамены.items(), start=1):
    print("{}) {} {}".format(i, экзамен, балл))

ok = False
for необходимый_экзамен, баллы in необходимые_экзамены.items():
    if сданные_экзамены[необходимый_экзамен] < баллы:
        break
else:
    ok = True

print("Вы можете к нам поступить!" if ok else "Увы...")


"""
Ошибки (номера строк через пробел, данная строка - №2): 19 20 26 27
"""

# В программе хранится словарь вступительных экзаменов вида Предмет=Баллы.
# Узнать, проходит ли абитуриент на специальность, если нужно сдать
# все перечисленные экзамены с не меньшим количеством баллов.

необходимые_экзамены = {
    "Информатика": 80,
    "Математика": 85,
    "Русский язык": 75
}

print("""Для определения возможности поступления, необходима информация о Вас.

Для ввода экзамена и баллов введите их через |: Химия | 40.
Для завершения ввода нажмите Enter.
""")

сданные_экзамены = {}
while True:
    try:
        ввод = input("").strip()
        if ввод == "":
            break

        if "|" not in ввод:
            print("Ошибка: используйте формат 'Экзамен | Балл'. Попробуйте снова.")
            continue

        экзамен, балл = [x.strip() for x in ввод.split("|")]

        try:
            сданные_экзамены[экзамен] = int(балл)
        except ValueError:
            print(f"Ошибка: '{балл}' не является числом. Попробуйте снова.")
            continue

    except Exception as e:
        print(f"Произошла ошибка: {e}. Попробуйте снова.")
        continue

print("Ваши экзамены:")
for i, (экзамен, балл) in enumerate(сданные_экзамены.items(), start=1):
    print("{}) {} {}".format(i, экзамен, балл))

try:
    ok = True
    for необходимый_экзамен, баллы in необходимые_экзамены.items():
        if необходимый_экзамен not in сданные_экзамены:
            ok = False
            break
        if сданные_экзамены[необходимый_экзамен] < баллы:
            ok = False
            break

    print("Вы можете к нам поступить!" if ok else "Увы...")
except Exception as e:
    print(f"Произошла ошибка при проверке результатов: {e}")
